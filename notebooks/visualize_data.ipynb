# %%
import pandas as pd

df = pd.read_csv("../data/processed/freelancer_projects_clean.csv")

df
# Out:
#            platform            category  \
# 0    Freelancer.com  Python Development
# 1    Freelancer.com  Python Development
# 2    Freelancer.com  Python Development
# 3    Freelancer.com  Python Development
# 4    Freelancer.com  Python Development
# ..              ...                 ...
# 655  Freelancer.com         Mobile Apps
# 656  Freelancer.com         Mobile Apps
# 657  Freelancer.com         Mobile Apps
# 658  Freelancer.com         Mobile Apps
# 659  Freelancer.com         Mobile Apps
#
#                                                  title  \
# 0     AI Enhanced Wearable Reading Assistant Prototype
# 1                         Paymob & WhatsApp Odoo Setup
# 2              Desktop Installment Management Software
# 3                      Custom Software Task Automation
# 4    Auto Album Designing Desktop Software (AI-Base...
# ..                                                 ...
# 655                    Persuasive Copy for Sales Boost
# ...
